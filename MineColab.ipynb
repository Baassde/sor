# %% [markdown]
# ```
# ███╗   ███╗██╗███╗   ██╗███████╗ ██████╗ ██████╗ ██╗      █████╗ ██████╗
# ████╗ ████║██║████╗  ██║██╔════╝██╔════╝██╔═══██╗██║     ██╔══██╗██╔══██╗
# ██╔████╔██║██║██╔██╗ ██║█████╗  ██║     ██║   ██║██║     ███████║██████╔╝
# ██║╚██╔╝██║██║██║╚██╗██║██╔══╝  ██║     ██║   ██║██║     ██╔══██║██╔══██╗
# ██║ ╚═╝ ██║██║██║ ╚████║███████╗╚██████╗╚██████╔╝███████╗██║  ██║██████╔╝
# ╚═╝     ╚═╝╚═╝╚═╝  ╚═══╝╚══════╝ ╚═════╝ ╚═════╝ ╚══════╝╚═╝  ╚═╝╚═════╝
# ```
# **Run a Minecraft Server on Google Colab!**
#
# ---
#
# The script below will run your server. You'll have to create a server first to be able to use it - don't worry, the scripts below will do the majority of the work for you. You might also want to change the default region to your region, check below.

# %%
import os
import re
import json

# Update the package lists
# !sudo apt update &>/dev/null && echo "apt cache successfully updated" || echo "apt cache update failed, you might receive stale packages"
# Install OpenJDK 17
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/ &>/dev/null || echo "Failed to add repo. Still can be ignored if openjdk17 gets installed."
# !sudo apt-get install openjdk-21-jre-headless &>/dev/null && echo "Yay! Openjdk17 has been successfully installed." || echo "Failed to install OpenJdk17."
#Perform java version check
java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'
if java_ver[0] == "21" :
  print("Openjdk17 is working correctly, you are good to go.")
else:
  print("Openjdk17 doesn't seems to be installed or isn't working, falling back to java", java_ver[0], ". You might experience reduced performance. Minecraft 1.17 and above might fail to launch.")

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change directory to the Minecraft server folder on Google Drive
# %cd "/content/drive/My Drive/Minecraft-server"
# !ls #list the directory contents (to verify that working directory was changed)

# Import config file.
if os.path.isfile("colabconfig.json"):
  colabconfig = json.load(open("colabconfig.json"))
else:
  colabconfig = {"server_type": "generic"} # using default, if config doesn't exists.
  json.dump(colabconfig, open("colabconfig.json",'w'))

# Server jar names.
jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'server.jar'}
jar_name = jar_list[colabconfig["server_type"]]

# Java arguments.
if colabconfig["server_type"] == "paper":
  server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"
else:
  server_flags = "" # aiker's flags might negatively impact performance on non-paper servers.
memory_allocation = "-Xmx6144M -Xms6144M"

# Chose the tunnle service you want to use
# Available options: ngrok, argo, playit
tunnel_service = "playit"
print("Procedding to use", tunnel_service)


if tunnel_service == "ngrok":
  # !pip -q install pyngrok
  from pyngrok import conf, ngrok

  # Ask for the ngrok authtoken
  print("Get your authtoken from https://dashboard.ngrok.com/auth")
  import getpass
  authtoken = getpass.getpass()  # input your Ngrok auth token everytime you run the cell or simply replace "getpass.getpass()" with your token in "double quotes"
  ! ngrok authtoken $authtoken # login to ngrok

  # Sets default ngrok region
  conf.get_default().region = 'us'  # Change this to whichever region you want

  # Connect to ngrok
  url = ngrok.connect(25565, 'tcp')
  print('Your server address is ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

  print('Starting server...')
  # !java $memory_allocation $server_flags -jar $jar_name nogui

elif tunnel_service == "playit":
  ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
  ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
  ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
  print('Starting server...')
  ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

else:
  # Download & make argo executable
  # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
  # !chmod +x cloudflared-linux-amd64
  print('Starting server...')
  # !./cloudflared-linux-amd64 tunnel --url tcp://127.0.0.1:25565 & java $memory_allocation $server_flags -jar $jar_name nogui
# Out:
# apt cache successfully updated
# Yay! Openjdk17 has been successfully installed.
# Openjdk17 is working correctly, you are good to go.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Minecraft-server
# cloudflared-linux-amd64    installer.log		    run.sh
# cloudflared-linux-amd64.1  libraries			    server-icon.png
# colabconfig.json	   logs				    server.jar
# config			   mods				    start.bat
# defaultconfigs		   neoforge-21.1.172-installer.jar  start.sh
# eula.txt		   run.bat			    user_jvm_args.txt
# Procedding to use argo
# --2025-08-19 13:33:45--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.8.0/cloudflared-linux-amd64 [following]
# --2025-08-19 13:33:45--  https://github.com/cloudflare/cloudflared/releases/download/2025.8.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/f51b16ea-9165-4877-a4ed-498a2db75169?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-19T14%3A23%3A37Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-19T13%3A23%3A16Z&ske=2025-08-19T14%3A23%3A37Z&sks=b&skv=2018-11-09&sig=j1GWvt3Xiq27FZmjPhzyitTWHl05fjZ7qWIXnCjvx3M%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NTYxMDY4NiwibmJmIjoxNzU1NjEwMzg2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.kDnq4C8xQaOORJ_wT2oVPagOgsiJW3W5nGBsDsDLuoc&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2025-08-19 13:33:45--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/f51b16ea-9165-4877-a4ed-498a2db75169?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-08-19T14%3A23%3A37Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-08-19T13%3A23%3A16Z&ske=2025-08-19T14%3A23%3A37Z&sks=b&skv=2018-11-09&sig=j1GWvt3Xiq27FZmjPhzyitTWHl05fjZ7qWIXnCjvx3M%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NTYxMDY4NiwibmJmIjoxNzU1NjEwMzg2LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.kDnq4C8xQaOORJ_wT2oVPagOgsiJW3W5nGBsDsDLuoc&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41181190 (39M) [application/octet-stream]
# Saving to: ‘cloudflared-linux-amd64.2’
#
# cloudflared-linux-a 100%[===================>]  39.27M  50.6MB/s    in 0.8s
#
# 2025-08-19 13:33:46 (50.6 MB/s) - ‘cloudflared-linux-amd64.2’ saved [41181190/41181190]
#
# Starting server...
# 2025-08-19T13:33:47Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-08-19T13:33:47Z INF Requesting new quick Tunnel on trycloudflare.com...
# [13:33:52.513] [main/INFO] [Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.neoForgeVersion, 21.1.172, --fml.fmlVersion, 4.0.39, --fml.mcVersion, 1.21.1, --fml.neoFormVersion, 20240808.144430, nogui]
# [13:33:52.520] [main/INFO] [Launcher/MODLAUNCHER]: JVM identified as Ubuntu OpenJDK 64-Bit Server VM 21.0.8+9-Ubuntu-0ubuntu122.04.1
# [13:33:52.524] [main/INFO] [Launcher/MODLAUNCHER]: ModLauncher 11.0.4+main.d2e20e43 starting: java version 21.0.8 by Ubuntu; OS Linux arch amd64 version 6.1.123+
# 2025-08-19T13:33:52Z INF +--------------------------------------------------------------------------------------------+
# 2025-08-19T13:33:52Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2025-08-19T13:33:52Z INF |  https://sufficient-data-anticipated-detective.trycloudflare.com                           |
# 2025-08-19T13:33:52Z INF +--------------------------------------------------------------------------------------------+
# 2025-08-19T13:33:52Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2025-08-19T13:33:52Z INF Version 2025.8.0 (Checksum c7d3a69da0f7b9b1bc1ddcb0597d3552bcd7c15f8bbaba463dc489b94b7544ee)
# 2025-08-19T13:33:52Z INF GOOS: linux, GOVersion: go1.24.4, GoArch: amd64
# 2025-08-19T13:33:52Z INF Settings: map[ha-connections:1 protocol:quic url:tcp://127.0.0.1:25565]
# 2025-08-19T13:33:52Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2025-08-19T13:33:52Z INF Generated Connector ID: b9ed18fc-3ddc-4057-afda-c17ad39f5c4b
# 2025-08-19T13:33:52Z INF Initial protocol quic
# 2025-08-19T13:33:52Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-08-19T13:33:52Z INF ICMP proxy will use :: as source for IPv6
# 2025-08-19T13:33:52Z ERR Cannot determine default origin certificate path. No file cert.pem in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]. You need to specify the origin certificate path by specifying the origincert option in the configuration file, or set TUNNEL_ORIGIN_CERT environment variable originCertPath=
# 2025-08-19T13:33:52Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2025-08-19T13:33:52Z INF ICMP proxy will use :: as source for IPv6
# 2025-08-19T13:33:52Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2025-08-19T13:33:52Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.227
# 2025/08/19 13:33:52 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# [13:33:53.221] [main/INFO] [loading.ImmediateWindowHandler/]: ImmediateWindowProvider not loading because launch target is forgeserver
# 2025-08-19T13:33:53Z INF Registered tunnel connection connIndex=0 connection=79255bf4-d327-470c-9354-a52ed0433803 event=0 ip=198.41.192.227 location=atl01 protocol=quic
# [13:33:53.385] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.7 Source=union:/content/drive/My%20Drive/Minecraft-server/libraries/net/fabricmc/sponge-mixin/0.15.2+mixin.0.8.7/sponge-mixin-0.15.2+mixin.0.8.7.jar%2373!/ Service=ModLauncher Env=SERVER
# [13:33:54.401] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "server-1.21.1-20240808.144430-srg.jar" [locator: production server provider +net.neoforged:neoforge:21.1.172:server]
# [13:33:54.472] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "neoforge-21.1.172-universal.jar" [locator: PathBasedLocator[name=neoforge, paths=[libraries/net/neoforged/neoforge/21.1.172/neoforge-21.1.172-universal.jar]], reader: mod manifest]
# [13:33:54.498] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "almanac-1.21.x-neoforge-1.0.2.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.521] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "Clumps-neoforge-1.21.1-19.0.0.1.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.630] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "Cobblemon-neoforge-1.6.0+1.21.1.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.667] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "ferritecore-7.0.2-neoforge.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.682] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlinforforge-5.8.0-all.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.696] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "KryptonFoxified-0.1.0+mc1.21.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.711] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "letmedespawn-1.21.x-neoforge-1.5.0.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.725] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "lithium-neoforge-0.15.0+mc1.21.1.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:54.747] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "monsters_in_the_closet-1.0.3+1.21-forge.jar" [locator: {mods folder locator at /content/drive/My Drive/Minecraft-server/mods}, reader: mod manifest]
# [13:33:55.615] [main/INFO] [loading.moddiscovery.locators.JarInJarDependencyLocator/]: Found 14 dependencies adding them to mods collection
# [13:33:55.616] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found gamelibrary file "mixinextras-neoforge-0.4.1.jar" [parent: neoforge-21.1.172-universal.jar, locator: jarinjar, reader: mod manifest]
# [13:33:55.617] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlinx-coroutines-jdk8-1.10.2.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.618] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "net.neoforged.neoforge-coremods-21.1.172.jar" [parent: neoforge-21.1.172-universal.jar, locator: jarinjar, reader: mod manifest]
# [13:33:55.618] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlin-stdlib-jdk7-2.1.20.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.619] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlin-stdlib-jdk8-2.1.20.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.620] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "thedarkcolour.kfflang-5.8.0.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar, reader: mod manifest]
# [13:33:55.620] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found gamelibrary file "thedarkcolour.kfflib-5.8.0.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar, reader: mod manifest]
# [13:33:55.621] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlinx-serialization-core-jvm-1.8.1.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.621] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found mod file "thedarkcolour.kffmod-5.8.0.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar, reader: mod manifest]
# [13:33:55.622] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlin-stdlib-2.1.20.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.622] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlin-reflect-2.1.20.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.623] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlinx-serialization-json-jvm-1.8.1.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.626] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "velocity-native-3.3.0-SNAPSHOT.jar" [parent: KryptonFoxified-0.1.0+mc1.21.jar, locator: jarinjar]
# [13:33:55.626] [main/INFO] [loading.moddiscovery.ModDiscoverer/SCAN]: Found library file "kotlinx-coroutines-core-jvm-1.10.2.jar" [parent: kotlinforforge-5.8.0-all.jar, locator: jarinjar]
# [13:33:55.630] [main/INFO] [loading.moddiscovery.ModDiscoverer/]:
#      Mod List:
# 		Name Version (Mod Id)
#
# 		Almanac 1.0.2 (almanac)
# 		Clumps 19.0.0.1 (clumps)
# 		Cobblemon 1.6.0+1.21.1 (cobblemon)
# 		Ferrite Core 7.0.2 (ferritecore)
# 		Kotlin For Forge 5.8.0 (kotlinforforge)
# 		KryptonFoxified 0.1.0+mc1.21 (krypton)
# 		Let Me Despawn 1.5.0 (letmedespawn)
# 		Lithium 0.15.0+mc1.21.1 (lithium)
# 		Minecraft 1.21.1 (minecraft)
# 		Monsters In The Closet 1.0.3+1.21-forge (monsters_in_the_closet)
# 		NeoForge 21.1.172 (neoforge)
# [13:33:57.551] [main/INFO] [mixin/]: Compatibility level set to JAVA_21
# [13:33:57.697] [main/INFO] [LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments [nogui]
# [13:33:58.044] [main/INFO] [LithiumConfig/]: Option 'mixin.experimental.entity.block_caching.suffocation' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.suffocation=false'.
# [13:33:58.049] [main/INFO] [LithiumConfig/]: Option 'mixin.experimental.entity.block_caching.block_support' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_support=false'.
# [13:33:58.050] [main/INFO] [LithiumConfig/]: Option 'mixin.experimental.entity.block_caching.block_touching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching.block_touching=false'.
# [13:33:58.050] [main/INFO] [LithiumConfig/]: Option 'mixin.experimental.entity.block_caching' requires 'mixin.util.block_tracking=true' but found 'false'. Setting 'mixin.experimental.entity.block_caching=false'.
# [13:33:58.055] [main/INFO] [Lithium/]: Loaded configuration file for Lithium: 146 options available, 0 override(s) found
# [13:33:58.098] [main/WARN] [mixin/]: Reference map 'monsters_in_the_closet.refmap.json' for monsters_in_the_closet.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.106] [main/WARN] [mixin/]: Reference map 'clumps.refmap.json' for clumps.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.375] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.predicates.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.396] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.fastmap.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.426] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.mrl.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.451] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.dedupmultipart.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.458] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.blockstatecache.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.469] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.dedupbakedquad.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.473] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.threaddetec.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.483] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.modelsides.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:33:58.491] [main/WARN] [mixin/]: Reference map '${refmap_target}refmap.json' for ferritecore.accessors.mixin.json could not be read. If this is a development environment you can ignore this message
# [13:34:02.780] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/components/AbstractSelectionList (java.lang.ClassNotFoundException: net.minecraft.client.gui.components.AbstractSelectionList)
# [13:34:02.782] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.components.AbstractSelectionList was not found mixins.cobblemon-common.json:accessor.EntryListWidgetAccessor from mod cobblemon
# [13:34:02.804] [main/WARN] [mixin/]: Error loading class: juuxel/adorn/block/variant/BlockVariantSets (java.lang.ClassNotFoundException: juuxel.adorn.block.variant.BlockVariantSets)
# [13:34:02.804] [main/WARN] [mixin/]: @Mixin target juuxel.adorn.block.variant.BlockVariantSets was not found mixins.cobblemon-common.json:invoker.AdornRegisterInvoker from mod cobblemon
# [13:34:04] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.4.1).
# 2025-08-19T13:36:22Z ERR  error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 destAddr=tcp://127.0.0.1:25565 event=1 ingressRule=0 originService=tcp://127.0.0.1:25565
# 2025-08-19T13:36:22Z ERR Request failed error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 dest=https://sufficient-data-anticipated-detective.trycloudflare.com/ event=0 ip=198.41.192.227 type=http
# 2025-08-19T13:36:23Z ERR  error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 destAddr=tcp://127.0.0.1:25565 event=1 ingressRule=0 originService=tcp://127.0.0.1:25565
# 2025-08-19T13:36:23Z ERR Request failed error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 dest=https://sufficient-data-anticipated-detective.trycloudflare.com/favicon.ico event=0 ip=198.41.192.227 type=http
# 2025-08-19T13:36:33Z ERR  error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 destAddr=tcp://127.0.0.1:25565 event=1 ingressRule=0 originService=tcp://127.0.0.1:25565
# 2025-08-19T13:36:33Z ERR Request failed error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 dest=https://sufficient-data-anticipated-detective.trycloudflare.com/favicon.ico event=0 ip=198.41.192.227 type=http
# 2025-08-19T13:36:34Z ERR  error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 destAddr=tcp://127.0.0.1:25565 event=1 ingressRule=0 originService=tcp://127.0.0.1:25565
# 2025-08-19T13:36:34Z ERR Request failed error="dial tcp 127.0.0.1:25565: connect: connection refused" connIndex=0 dest=https://sufficient-data-anticipated-detective.trycloudflare.com/favicon.ico event=0 ip=198.41.192.227 type=http
# 2025-08-19T13:36:42Z INF Initiating graceful shutdown due to signal interrupt ...
# 2025-08-19T13:36:42Z ERR Failed to serve tunnel connection error="context canceled" connIndex=0 event=0 ip=198.41.192.227
# 2025-08-19T13:36:42Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.227
# 2025-08-19T13:36:42Z ERR no more connections active and exiting
# 2025-08-19T13:36:42Z INF Tunnel server stopped
# 2025-08-19T13:36:42Z INF Metrics server stopped

# %% [markdown]
# # Make-a-Server
#
# The code below will download a server for you and accept the EULA. After running these scripts, your server will be ready to run.

# %% [markdown]
# **Download the Minecraft server**
#
# The code below will download Paper, a high-performance fork of the Vanilla server.
# Other server platforms can be used by placing the server.jar in the Drive folder manually.

# %%
# Replace "1.19.2" with your desired server version.
# Available versions:
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8
# Newer versions might work too, however this isn't guaranteed.
version = '1.19.2'
forge_version = "43.2.8"  # If you are going to use forge

#Chose server type. Currently available versions: fabric, paper, forge
server_type = 'paper'

from google.colab import drive
import requests
import json


drive.mount('/content/drive')

! mkdir "/content/drive/My Drive/Minecraft-server"
# %cd "/content/drive/My Drive/Minecraft-server"

if server_type == "paper":
  a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)
  b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))
  print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])

  url = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

  jar_name = "server.jar"
print('Downloading to Google Drive...')
elif server_type == "fabric":
  url = "https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.7.4/fabric-installer-0.7.4.jar"
  jar_name = "fabric-installer.jar"
elif server_type == "forge":
  url = f"https://maven.minecraftforge.net/net/minecraftforge/forge/{version}-{forge_version}/forge-{version}-{forge_version}-installer.jar"
  jar_name = "server.jar"


r = requests.get(url)

if r.status_code is 200:
  with open('/content/drive/My Drive/Minecraft-server/' + jar_name, 'wb') as f:
    f.write(r.content)
else:
  print('Error '+ str(r.status_code) + '! Most likely you entered a unsupported version. Try running the code again if you think that shouldn\'t have happened.')

# Running specific install path.
if server_type == "fabric":
  # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft
elif server_type == "forge":
  # !java -jar server.jar --installServer

colabconfig = {"server_type": server_type}
json.dump(colabconfig, open("colabconfig.json",'w'))

print('Done!')

# %% [markdown]
# **Automatically accept the EULA**

# %%
# Please read the file stored in your server folder before running this command.
# Also, go to https://www.minecraft.net/en-us/eula to read Minecraft's EULA.

# Make sure Drive is mounted
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Minecraft-server"
# !echo "eula=true" >> eula.txt

# %% [markdown]
# # Debug
# SSH access to host OS - Thanks to [colab-ssh](https://github.com/WassimBenzarti/colab-ssh).
#
# <p style="color:red;">YOU MIGHT GET BANNED</p>

# %%
#@title Colab-ssh tunnel
#@markdown Execute this cell to open the ssh tunnel. Check [colab-ssh documentation](https://github.com/WassimBenzarti/colab-ssh) for more details.

# Install colab_ssh on google colab
# !pip install colab_ssh --upgrade

from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
ssh_tunnel_password = "<PUT_YOUR_PASSWORD_HERE>" #@param {type: "string"}
launch_ssh_cloudflared(password=ssh_tunnel_password)

# %%
#Get public address (ngrok)
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
## For inspecting the minecraft server directory ##
# %cd "/content/drive/My Drive/Minecraft-server"
# !ls
